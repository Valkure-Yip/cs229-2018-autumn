# %% [markdown]
# # Independent Component Analysis (ICA)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import FastICA
from sklearn.datasets import load_iris

# Loading the iris dataset
iris = load_iris()
X = iris.data

# Creating an ICA object and fitting the data
ica = FastICA(n_components=2)
X_transformed = ica.fit_transform(X)

# Plotting the transformed data
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], c=iris.target, s=50, cmap='viridis')
plt.title('Independent Component Analysis')
plt.xlabel('IC1')
plt.ylabel('IC2')
plt.show()
# Out:
# /Users/zhitong.ye/miniconda3/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:542: FutureWarning: Starting in v1.3, whiten='unit-variance' will be used by default.
#   warnings.warn(
